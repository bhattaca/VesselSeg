# %%
import os
import sys
print(os.getcwd())
os.chdir("C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models")
sys.path.append("C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\")
sys.path.append("C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\research\\")
sys.path.append("C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\research\\slim")
print (sys.path)
CUDA_VISIBLE_DEVICES=1
# Out:
# C:\Users\u6abhatt\Documents\Python Scripts
# ['', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow\\python36.zip', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow\\DLLs', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow\\lib', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow\\lib\\site-packages', 'C:\\Users\\u6abhatt\\AppData\\Local\\Continuum\\anaconda3\\envs\\tensorflow\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\u6abhatt\\.ipython', 'C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\', 'C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\research\\', 'C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\models\\research\\slim']

# %%
run research/gan/mnist/train.py --train_log_dir="C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\tmp\\output\\" --dataset_dir="C:\\Users\\u6abhatt\\Documents\\Work\\Code\\GAN\\mnist-data\\" --max_number_of_steps=201 --gan_type="unconditional"
# Out:
# INFO:tensorflow:Summary name Generator/fully_connected/weights:0 is illegal; using Generator/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name Generator/fully_connected/BatchNorm/beta:0 is illegal; using Generator/fully_connected/BatchNorm/beta_0 instead.
# INFO:tensorflow:Summary name Generator/fully_connected_1/weights:0 is illegal; using Generator/fully_connected_1/weights_0 instead.
# INFO:tensorflow:Summary name Generator/fully_connected_1/BatchNorm/beta:0 is illegal; using Generator/fully_connected_1/BatchNorm/beta_0 instead.
# INFO:tensorflow:Summary name Generator/Conv2d_transpose/weights:0 is illegal; using Generator/Conv2d_transpose/weights_0 instead.
# INFO:tensorflow:Summary name Generator/Conv2d_transpose/BatchNorm/beta:0 is illegal; using Generator/Conv2d_transpose/BatchNorm/beta_0 instead.
# INFO:tensorflow:Summary name Generator/Conv2d_transpose_1/weights:0 is illegal; using Generator/Conv2d_transpose_1/weights_0 instead.
# ...

# %%
def _parse_function(filename):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_png(image_string)
    image_decoded = tf.image.rgb_to_grayscale (image_decoded)
    image = tf.cast(image_decoded, tf.float32)
    print ( "IMAGE SISZE***", tf.size( image));
    image_resized = tf.image.resize_images(image, [28, 28])
    return image_resized



batch_size = 32
with tf.device('/cpu:0'):
    #images, _, _ = data_provider.provide_data('train', batch_size, MNIST_DATA_DIR)
    #images = tf.data.Dataset.list_files("D:\\ArindamData\\pix2pix-tensorflow\\retina_val4C1\\images\\*.png")
    filenames = (glob.glob("D:\\ArindamData\\pix2pix-tensorflow\\retina\\train\\*.png"))
    print ( len(filenames))
    # step 2: create a dataset returning slices of `filenames`
    dataset = tf.data.Dataset.from_tensor_slices((filenames))
    
    images = dataset.map(_parse_function)
    images = images.batch(10);
    print ( "OUTPUT TYPE ", images.output_types)
    print ( "OUTPUT SHAPE ", images.output_shapes)

# %%
import tensorflow as tf
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
